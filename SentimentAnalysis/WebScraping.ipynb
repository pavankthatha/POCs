# %%
'''
Created on Apr 3, 2017

@author: Xuebin Wei
www.lbsocial.net
Extract texts from major news media webpages 
Very rough extraction
'''
from bs4 import BeautifulSoup
import urllib.request
import re

# %%
'''
for any webpages, extract all the visible texts
'''
 
html = urllib.request.urlopen('https://www.amazon.com/TiVo-BOLT-500-DVR-Version/product-reviews/B013X8YI5I') # put the url here
html = urllib.request.urlopen('https://www.amazon.com/TiVo-VOX-Remote-BOLT/product-reviews/B07634QZPL') # put the url here

soup = BeautifulSoup(html.read(), 'html.parser')
texts = soup.findAll(text=True)

def visible(element):
     if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
        return False
     elif re.match('<!--.*-->', str(element)):
        return False
     elif re.match('[if * <![endif]', str(element)):
        return False
     return True
visible_texts = filter(visible, texts)

'''
 write the texts into a txt file
'''
with open('amazon_vox.txt', 'bw') as outfile: #define the location of the output
     for text in visible_texts:
        try:
             print(text.encode('utf-8'))
 
             outfile.write(text.encode('utf-8'))
        except:
            pass
# Out:
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'&&&Portal&Delimiter&&&'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Interesting Finds Updated Daily'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Amazon'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n    Try Prime\n  '
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'All'
# b'\n'
# b'\n'
# b'\n'
# b'Select the department you want to search in'
# b'\n'
# b'\n'
# b'All Departments'
# b'\n'
# b'Cyber Monday Deals Week'
# b'\n'
# b'Alexa Skills'
# b'\n'
# b'Amazon Devices'
# b'\n'
# b'Amazon Video'
# b'\n'
# b'Amazon Warehouse Deals'
# b'\n'
# b'Appliances'
# b'\n'
# b'Apps & Games'
# b'\n'
# b'Arts, Crafts & Sewing'
# b'\n'
# b'Automotive Parts & Accessories'
# b'\n'
# b'Baby'
# b'\n'
# b'Beauty & Personal Care'
# b'\n'
# b'Books'
# b'\n'
# b'CDs & Vinyl'
# b'\n'
# b'Cell Phones & Accessories'
# b'\n'
# b'Clothing, Shoes & Jewelry'
# b'\n'
# b'\xc2\xa0\xc2\xa0\xc2\xa0Women'
# b'\n'
# b'\xc2\xa0\xc2\xa0\xc2\xa0Men'
# b'\n'
# b'\xc2\xa0\xc2\xa0\xc2\xa0Girls'
# b'\n'
# b'\xc2\xa0\xc2\xa0\xc2\xa0Boys'
# b'\n'
# b'\xc2\xa0\xc2\xa0\xc2\xa0Baby'
# b'\n'
# b'Collectibles & Fine Art'
# b'\n'
# b'Computers'
# b'\n'
# b'Courses'
# b'\n'
# b'Credit and Payment Cards'
# b'\n'
# b'Digital Music'
# b'\n'
# b'Electronics'
# b'\n'
# b'Garden & Outdoor'
# b'\n'
# b'Gift Cards'
# b'\n'
# b'Grocery & Gourmet Food'
# b'\n'
# b'Handmade'
# b'\n'
# b'Health, Household & Baby Care'
# b'\n'
# b'Home & Business Services'
# b'\n'
# b'Home & Kitchen'
# b'\n'
# b'Industrial & Scientific'
# b'\n'
# b'Kindle Store'
# b'\n'
# b'Luggage & Travel Gear'
# b'\n'
# b'Luxury Beauty'
# b'\n'
# b'Magazine Subscriptions'
# b'\n'
# b'Movies & TV'
# b'\n'
# b'Musical Instruments'
# b'\n'
# b'Office Products'
# b'\n'
# b'Pet Supplies'
# b'\n'
# b'Prime Exclusive Savings'
# b'\n'
# b'Prime Pantry'
# b'\n'
# b'Software'
# b'\n'
# b'Sports & Outdoors'
# b'\n'
# b'Tools & Home Improvement'
# b'\n'
# b'Toys & Games'
# b'\n'
# b'Vehicles'
# b'\n'
# b'Video Games'
# b'\n'
# b'Wine'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Go'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n          Search\n        '
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Departments'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'EN'
# b'\n'
# b'\n'
# b'\xc2\xa0\n      '
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Hello. Sign in'
# b'Account & Lists'
# b'Sign in'
# b'Account & Lists'
# b'Orders'
# b'Try Prime'
# b'Cart'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Your Amazon.com'
# b'Cyber Monday Deals Week'
# b'Gift Cards'
# b'Registry'
# b'Sell'
# b'Help'
# b'Disability Customer Support '
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'TiVo VOX Remote for TiVo BOLT'
# b'\n'
# b'\n'
# b'\xe2\x80\xba'
# b'\n'
# b'\n'
# b'\n'
# b'Customer reviews'
# b'\n'
# b'\n'
# b'Customer reviews'
# b'3.2 out of 5 stars'
# b'9'
# b'3.2 out of 5 stars'
# b'5 star'
# b'45%'
# b'4 star'
# b'4 star (0%)'
# b'0%'
# b'3 star'
# b'11%'
# b'2 star'
# b'22%'
# b'1 star'
# b'22%'
# b'TiVo VOX Remote for TiVo BOLT'
# b'by'
# b'TiVo'
# b'Price:'
# b'$39.99'
# b'+ Free shipping with Amazon Prime'
# b'Write a review'
# b'Add to Cart'
# b'Add to Wish List'
# b'\n'
# b'This page works best with JavaScript. Disabling it will result in some disabled or missing features. You can still see all customer reviews for the product.'
# b'\n'
# b'\n'
# b'Top positive review'
# b'See all 4 positive reviews'
# b'\xe2\x80\xba '
# b'\n          10 people found this helpful'
# b'\n'
# b'5.0 out of 5 stars'
# b'Tivo Has Nailed Voice Control -- Worth the Wait'
# b'By'
# b'Bruce D. Namerow'
# b'on November 5, 2017'
# b"Tivo made us wait quite a long time to get a voice-controlled remote, but they have really nailed it. I paired this with my existing Tivo Bolt -- took just a minute and was easy to do, although I did have to use the advanced pairing since it didn't automatically connect. I was surprised that the bluetooth connection actually works better than my old RF Tivo remote -- much faster and more responsive when you hit a button. Wow. Even better, I have my TiVo in a closed closet and the Bluetooth seems to connect more reliably RF."
# b'Then there is the voice control. First, make sure you have the new TiVo update, which you can request directly at Tivo.com (although I\'m sure it will be automatically downloaded to all customers soon). It understands my voice extremely well, even with noise in the room. You can ask for things like a tv station "NBC" and it will take you directly there. Ask it for a game like "Michigan Football" and presto, you get the next upcoming game with the option to record. Or ask it for a show you have recorded, and it also pops up to start watching. For the most part, it understands everything you ask it, but when I asked for "60 Minutes" it couldn\'t help. Not sure why, but I\'m sure they\'ll keep refining it.'
# b"Finally, I like the new Tivo interface, but it has a few quirks. First, they took away my favorite version of the TiVo guide -- not sure why. I guess now with the voice remote, it won't matter much. It also seems to show recorded episodes with the oldest showing first -- I prefer the opposite. Overall, it's gotten a little overwhelming and confusing, but perhaps will get better once I use it more."
# b'\n'
# b'\n'
# b'Read more'
# b'\n'
# b'Top critical review'
# b'See all 5 critical reviews'
# b'\xe2\x80\xba '
# b'3.0 out of 5 stars'
# b'Warning about VOX with Mini'
# b'By'
# b'JustDave1'
# b'on November 26, 2017'
# b'TIVO VOX remote works great with my TIVO Bolt, but would not RF pair to a Mini without a dongle for the Mini that is not included unless you buy the remote directly from TIVO. Without this pairing the Voice button will not work with the new TIVO Experience and you only have an IR based remote.'
# b'\n'
# b'\n'
# b'Read more'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Search'
# b'Sort by'
# b'Top rated'
# b'Most recent'
# b'Top rated'
# b'Filter by'
# b'All reviewers'
# b'Verified purchase only'
# b'All reviewers'
# b'All stars'
# b'5 star only'
# b'4 star only'
# b'3 star only'
# b'2 star only'
# b'1 star only'
# b'All positive'
# b'All critical'
# b'All stars'
# b'Text, image, video'
# b'Image and video reviews only'
# b'Text, image, video'
# b'There was a problem filtering reviews right now. Please try again later.'
# b'3.0 out of 5 stars'
# b'Warning about VOX with Mini'
# b'By'
# b'JustDave1'
# b'on November 26, 2017'
# b'Verified Purchase'
# b'TIVO VOX remote works great with my TIVO Bolt, but would not RF pair to a Mini without a dongle for the Mini that is not included unless you buy the remote directly from TIVO. Without this pairing the Voice button will not work with the new TIVO Experience and you only have an IR based remote.'
# b'0'
# b'Comment'
# b'|'
# b'Was this review helpful to you?'
# b'Yes'
# b'No'
# b'Report abuse'
# b'Comment'
# b'Insert product link'
# b"Paste the product's web address below:"
# b'Product not found. Only products offered on Amazon can be linked.'
# b'Select'
# b"What's this?"
# b'What are product links?'
# b'In the text of your review, you can link directly to any product offered on Amazon.com. To insert a product link, follow these steps:'
# b'1. Find the product you want to reference on Amazon.com'
# b'2. Copy the web address of the product'
# b'3. Click '
# b'Insert product link'
# b'4. Paste the web address in the box'
# b'5. Click '
# b'Select'
# b'6. Selecting the item displayed will insert text that looks like this: '
# b'\n        [[ASIN:014312854X'
# b'Hamlet (The Pelican Shakespeare)]]\n      '
# b'7. When your review is displayed on Amazon.com, this text will be transformed into a hyperlink, like so:'
# b'Hamlet (The Pelican Shakespeare)'
# b'You are limited to 10 product links in your review, and your link text may not be longer than 256 characters.'
# b'Talk about why you like this review, or ask a question.'
# b'Please write at least one word'
# b'You must be in good standing in the Amazon community to post.'
# b'Your message will not be posted. Please see our guidelines regarding objectionable content.'
# b'You must purchase at least one item from Amazon to post a comment'
# b'A problem occurred while submitting your comment. Please try again later.'
# b'\n        Guidelines'
# b'\n'
# b'Sign in to comment'
# b'\n'
# b'Showing '
# b'0'
# b'Sort by:'
# b'\n'
# b'Newest'
# b'\n'
# b'\n'
# b'Oldest'
# b'\n'
# b'\n'
# b'There was a problem loading comments right now. Please try again later.'
# b'5.0 out of 5 stars'
# b'Tivo Has Nailed Voice Control -- Worth the Wait'
# b'By'
# b'Bruce D. Namerow'
# b'on November 5, 2017'
# b"Tivo made us wait quite a long time to get a voice-controlled remote, but they have really nailed it. I paired this with my existing Tivo Bolt -- took just a minute and was easy to do, although I did have to use the advanced pairing since it didn't automatically connect. I was surprised that the bluetooth connection actually works better than my old RF Tivo remote -- much faster and more responsive when you hit a button. Wow. Even better, I have my TiVo in a closed closet and the Bluetooth seems to connect more reliably RF."
# b'Then there is the voice control. First, make sure you have the new TiVo update, which you can request directly at Tivo.com (although I\'m sure it will be automatically downloaded to all customers soon). It understands my voice extremely well, even with noise in the room. You can ask for things like a tv station "NBC" and it will take you directly there. Ask it for a game like "Michigan Football" and presto, you get the next upcoming game with the option to record. Or ask it for a show you have recorded, and it also pops up to start watching. For the most part, it understands everything you ask it, but when I asked for "60 Minutes" it couldn\'t help. Not sure why, but I\'m sure they\'ll keep refining it.'
# b"Finally, I like the new Tivo interface, but it has a few quirks. First, they took away my favorite version of the TiVo guide -- not sure why. I guess now with the voice remote, it won't matter much. It also seems to show recorded episodes with the oldest showing first -- I prefer the opposite. Overall, it's gotten a little overwhelming and confusing, but perhaps will get better once I use it more."
# b'0'
# b'Comment'
# b'|'
# b'\n      10 people found this helpful.\n    '
# b'\n  Was this review helpful to you?'
# b'Yes'
# b'No'
# b'Report abuse'
# b'Comment'
# b'Insert product link'
# b"Paste the product's web address below:"
# b'Product not found. Only products offered on Amazon can be linked.'
# b'Select'
# b"What's this?"
# b'What are product links?'
# b'In the text of your review, you can link directly to any product offered on Amazon.com. To insert a product link, follow these steps:'
# b'1. Find the product you want to reference on Amazon.com'
# b'2. Copy the web address of the product'
# b'3. Click '
# b'Insert product link'
# b'4. Paste the web address in the box'
# b'5. Click '
# b'Select'
# b'6. Selecting the item displayed will insert text that looks like this: '
# b'\n        [[ASIN:014312854X'
# b'Hamlet (The Pelican Shakespeare)]]\n      '
# b'7. When your review is displayed on Amazon.com, this text will be transformed into a hyperlink, like so:'
# b'Hamlet (The Pelican Shakespeare)'
# b'You are limited to 10 product links in your review, and your link text may not be longer than 256 characters.'
# b'Talk about why you like this review, or ask a question.'
# b'Please write at least one word'
# b'You must be in good standing in the Amazon community to post.'
# b'Your message will not be posted. Please see our guidelines regarding objectionable content.'
# b'You must purchase at least one item from Amazon to post a comment'
# b'A problem occurred while submitting your comment. Please try again later.'
# b'\n        Guidelines'
# b'\n'
# b'Sign in to comment'
# b'\n'
# b'Showing '
# b'0'
# b'Sort by:'
# b'\n'
# b'Newest'
# b'\n'
# b'\n'
# b'Oldest'
# b'\n'
# b'\n'
# b'There was a problem loading comments right now. Please try again later.'
# b'5.0 out of 5 stars'
# b'Worth the Upgrade'
# b'By'
# b'southshore74'
# b'on November 18, 2017'
# b'Verified Purchase'
# b"WoW, Amazing, this remote was totaly worth the whole software upgrade (Tivo Experience) Not only can you say what show you want to watch but it will also bring up the channel. All you have to say is the Channel # or say what channel, HGTV or ESPN, etc. Pairing was easy and fast. If your that one person that has to write a negative review on setup, that means YOU did it wrong. I have had no issues with picture quality. Remember you must upgrade to the new Software first (which takes up to 3 days to do from the time of request), eventually it with come automatically, but for now you must request this with Tivo, It will not automatically happen. By the way none of the buttons are lighted, just like the old remotes, so don't be surprised. Don't worry you do not have to purchase new Tivo Boxes in order to use the new features, just upgrade the software and remote. The rewind and fast forward are also much faster now."
# b"Update 11/21/2017: Just activated my second remote, and it works flawlessly. Now moving on to the Mini's with the Remote with USB Dongle."
# b'0'
# b'Comment'
# b'|'
# b'\n      2 people found this helpful.\n    '
# b'\n  Was this review helpful to you?'
# b'Yes'
# b'No'
# b'Report abuse'
# b'Comment'
# b'Insert product link'
# b"Paste the product's web address below:"
# b'Product not found. Only products offered on Amazon can be linked.'
# b'Select'
# b"What's this?"
# b'What are product links?'
# b'In the text of your review, you can link directly to any product offered on Amazon.com. To insert a product link, follow these steps:'
# b'1. Find the product you want to reference on Amazon.com'
# b'2. Copy the web address of the product'
# b'3. Click '
# b'Insert product link'
# b'4. Paste the web address in the box'
# b'5. Click '
# b'Select'
# b'6. Selecting the item displayed will insert text that looks like this: '
# b'\n        [[ASIN:014312854X'
# b'Hamlet (The Pelican Shakespeare)]]\n      '
# b'7. When your review is displayed on Amazon.com, this text will be transformed into a hyperlink, like so:'
# b'Hamlet (The Pelican Shakespeare)'
# b'You are limited to 10 product links in your review, and your link text may not be longer than 256 characters.'
# b'Talk about why you like this review, or ask a question.'
# b'Please write at least one word'
# b'You must be in good standing in the Amazon community to post.'
# b'Your message will not be posted. Please see our guidelines regarding objectionable content.'
# b'You must purchase at least one item from Amazon to post a comment'
# b'A problem occurred while submitting your comment. Please try again later.'
# b'\n        Guidelines'
# b'\n'
# b'Sign in to comment'
# b'\n'
# b'Showing '
# b'0'
# b'Sort by:'
# b'\n'
# b'Newest'
# b'\n'
# b'\n'
# b'Oldest'
# b'\n'
# b'\n'
# b'There was a problem loading comments right now. Please try again later.'
# b'5.0 out of 5 stars'
# b'Works as Described!'
# b'By'
# b'SeaBoss'
# b'on November 8, 2017'
# b'Verified Purchase'
# b'This works really well! I\'m not overly fond of the button layout, but it\'s basically the same as other TiVo remotes. For this to work on my TiVo Bolt, I had to have TiVo support upgrade my Bolt unit with the "New Experience" guide software. It took them a little more than 24 hours to do that, but once it was updated the remote worked as advertised. Great voice searching capabilities. The upgraded guide is free, but I believe if you have a unit that\'s older (different model) than the Bolt, then you will need some kind of accessory unit to make those older TiVos compatible with the Vox Remote.'
# b'0'
# b'Comment'
# b'|'
# b'\n      2 people found this helpful.\n    '
# b'\n  Was this review helpful to you?'
# b'Yes'
# b'No'
# b'Report abuse'
# b'Comment'
# b'Insert product link'
# b"Paste the product's web address below:"
# b'Product not found. Only products offered on Amazon can be linked.'
# b'Select'
# b"What's this?"
# b'What are product links?'
# b'In the text of your review, you can link directly to any product offered on Amazon.com. To insert a product link, follow these steps:'
# b'1. Find the product you want to reference on Amazon.com'
# b'2. Copy the web address of the product'
# b'3. Click '
# b'Insert product link'
# b'4. Paste the web address in the box'
# b'5. Click '
# b'Select'
# b'6. Selecting the item displayed will insert text that looks like this: '
# b'\n        [[ASIN:014312854X'
# b'Hamlet (The Pelican Shakespeare)]]\n      '
# b'7. When your review is displayed on Amazon.com, this text will be transformed into a hyperlink, like so:'
# b'Hamlet (The Pelican Shakespeare)'
# b'You are limited to 10 product links in your review, and your link text may not be longer than 256 characters.'
# b'Talk about why you like this review, or ask a question.'
# b'Please write at least one word'
# b'You must be in good standing in the Amazon community to post.'
# b'Your message will not be posted. Please see our guidelines regarding objectionable content.'
# b'You must purchase at least one item from Amazon to post a comment'
# b'A problem occurred while submitting your comment. Please try again later.'
# b'\n        Guidelines'
# b'\n'
# b'Sign in to comment'
# b'\n'
# b'Showing '
# b'0'
# b'Sort by:'
# b'\n'
# b'Newest'
# b'\n'
# b'\n'
# b'Oldest'
# b'\n'
# b'\n'
# b'There was a problem loading comments right now. Please try again later.'
# b'1.0 out of 5 stars'
# b'" If you like the UI'
# b'By'
# b'Name withheld'
# b'on November 22, 2017'
# b'Before you buy the new VOX remote, try the new user interface, "Tivo Experience." If you like the UI, buy the remote. If you do not, don\'t waste your money. I do not like the new Experience UI - it is a huge departure from the user friendly Tivo UI. If you install Experience you must acknowledge that a downgrade will erase everything on your box. The process to downgrade from Experience is navigate to the Menu > Help > Reset to Defaults > Repeat Guided Setup. Enter Thumbs Down > Thumbs Down > Rewind > Rewind to display the Downgrade Your Tivo Box screen. All of your settings and recordings will be erased. The great Tivo UI has been altered dramatically = very bad change.'
# b'0'
# b'Comment'
# b'|'
# b'\n      3 people found this helpful.\n    '
# b'\n  Was this review helpful to you?'
# b'Yes'
# b'No'
# b'Report abuse'
# b'Comment'
# b'Insert product link'
# b"Paste the product's web address below:"
# b'Product not found. Only products offered on Amazon can be linked.'
# b'Select'
# b"What's this?"
# b'What are product links?'
# b'In the text of your review, you can link directly to any product offered on Amazon.com. To insert a product link, follow these steps:'
# b'1. Find the product you want to reference on Amazon.com'
# b'2. Copy the web address of the product'
# b'3. Click '
# b'Insert product link'
# b'4. Paste the web address in the box'
# b'5. Click '
# b'Select'
# b'6. Selecting the item displayed will insert text that looks like this: '
# b'\n        [[ASIN:014312854X'
# b'Hamlet (The Pelican Shakespeare)]]\n      '
# b'7. When your review is displayed on Amazon.com, this text will be transformed into a hyperlink, like so:'
# b'Hamlet (The Pelican Shakespeare)'
# b'You are limited to 10 product links in your review, and your link text may not be longer than 256 characters.'
# b'Talk about why you like this review, or ask a question.'
# b'Please write at least one word'
# b'You must be in good standing in the Amazon community to post.'
# b'Your message will not be posted. Please see our guidelines regarding objectionable content.'
# b'You must purchase at least one item from Amazon to post a comment'
# b'A problem occurred while submitting your comment. Please try again later.'
# b'\n        Guidelines'
# b'\n'
# b'Sign in to comment'
# b'\n'
# b'Showing '
# b'0'
# b'Sort by:'
# b'\n'
# b'Newest'
# b'\n'
# b'\n'
# b'Oldest'
# b'\n'
# b'\n'
# b'There was a problem loading comments right now. Please try again later.'
# b'2.0 out of 5 stars'
# b'More wasted potential from Tivo'
# b'By'
# b'Michael G.'
# b'on November 6, 2017'
# b"The new interface required for voice really misses the boat in usability.  The fonts are hard to read.  Basic navigation  takes more steps than previously, e.g., 5 steps to get to standby, 'playing' a show under my shows requires two steps after it is found (believe it, the PLAY button does not do anything!).  'My Shows' always goes back to the top of the list, not from where you left off.  'Deleting' a single episode also requires two steps (CLEAR opens another menu)."
# b"The long awaited voice commands are incomplete, e.g., you can 'GO TO' a station call letters but not it's channel number.  PLAY show does not."
# b'Search for ACADEMY AWARD WINNERS finds nothing.'
# b'It has a nice large preview screen on the main menu, but it shrinks as soon as you do anything!  It has a visual strip for things to do, but it seems to be random, i.e. it does not show your recordings from the beginning or from where you left off, but rather from some random location and often with shows already viewed.'
# b'TIVO, if you read this, please clean it up.  New interfaces should be smoother, easier to read, require fewer steps for basic functions.  You failed on all counts.'
# b'2'
# b'2 comments'
# b'|'
# b'\n      13 people found this helpful.\n    '
# b'\n  Was this review helpful to you?'
# b'Yes'
# b'No'
# b'Report abuse'
# b'Comment'
# b'Insert product link'
# b"Paste the product's web address below:"
# b'Product not found. Only products offered on Amazon can be linked.'
# b'Select'
# b"What's this?"
# b'What are product links?'
# b'In the text of your review, you can link directly to any product offered on Amazon.com. To insert a product link, follow these steps:'
# b'1. Find the product you want to reference on Amazon.com'
# b'2. Copy the web address of the product'
# b'3. Click '
# b'Insert product link'
# b'4. Paste the web address in the box'
# b'5. Click '
# b'Select'
# b'6. Selecting the item displayed will insert text that looks like this: '
# b'\n        [[ASIN:014312854X'
# b'Hamlet (The Pelican Shakespeare)]]\n      '
# b'7. When your review is displayed on Amazon.com, this text will be transformed into a hyperlink, like so:'
# b'Hamlet (The Pelican Shakespeare)'
# b'You are limited to 10 product links in your review, and your link text may not be longer than 256 characters.'
# b'Talk about why you like this review, or ask a question.'
# b'Please write at least one word'
# b'You must be in good standing in the Amazon community to post.'
# b'Your message will not be posted. Please see our guidelines regarding objectionable content.'
# b'You must purchase at least one item from Amazon to post a comment'
# b'A problem occurred while submitting your comment. Please try again later.'
# b'\n        Guidelines'
# b'\n'
# b'Sign in to comment'
# b'\n'
# b'Showing '
# b'0'
# b'Sort by:'
# b'\n'
# b'Newest'
# b'\n'
# b'\n'
# b'Oldest'
# b'\n'
# b'\n'
# b'There was a problem loading comments right now. Please try again later.'
# b'2.0 out of 5 stars'
# b'A Step backwards-- Not a learning Remote- Stick with the old slide pro remote instead'
# b'By'
# b'on November 24, 2017'
# b'I am a loyal TiVo user for the past 10+ years, so I was looking forward to this new VOX remote. and I really wanted it to work for me. Unfortunately, The VOX remote is a step backwards. My old slide pro remote was a learning remote and I was able to program it to turn ON/OFF BOTH the TV and the AV receiver. I CAN\'T DO THATt with the VOX remote.  It won\'t TURN OFF/ON two devices at the same time. Also, to skip  the Ads (which is a GREAT feature), on the old slide remote pro,  I push on the D button and it skips. You can do that on a VOX remote, but to use your voice, you have to push Voice and then speak "Skip", so two steps on the new VOX remote- push button and speak, while one step on the old slide remote- push D.'
# b"I are so disappointed in this new  VOX remote that I  have given up on it and I am not going to use it until it becomes a learning remote. This review is just want to warn others to the new VOX remote's shortcomings"
# b'0'
# b'Comment'
# b'|'
# b'\n      One person found this helpful.\n    '
# b'\n  Was this review helpful to you?'
# b'Yes'
# b'No'
# b'Report abuse'
# b'Comment'
# b'Insert product link'
# b"Paste the product's web address below:"
# b'Product not found. Only products offered on Amazon can be linked.'
# b'Select'
# b"What's this?"
# b'What are product links?'
# b'In the text of your review, you can link directly to any product offered on Amazon.com. To insert a product link, follow these steps:'
# b'1. Find the product you want to reference on Amazon.com'
# b'2. Copy the web address of the product'
# b'3. Click '
# b'Insert product link'
# b'4. Paste the web address in the box'
# b'5. Click '
# b'Select'
# b'6. Selecting the item displayed will insert text that looks like this: '
# b'\n        [[ASIN:014312854X'
# b'Hamlet (The Pelican Shakespeare)]]\n      '
# b'7. When your review is displayed on Amazon.com, this text will be transformed into a hyperlink, like so:'
# b'Hamlet (The Pelican Shakespeare)'
# b'You are limited to 10 product links in your review, and your link text may not be longer than 256 characters.'
# b'Talk about why you like this review, or ask a question.'
# b'Please write at least one word'
# b'You must be in good standing in the Amazon community to post.'
# b'Your message will not be posted. Please see our guidelines regarding objectionable content.'
# b'You must purchase at least one item from Amazon to post a comment'
# b'A problem occurred while submitting your comment. Please try again later.'
# b'\n        Guidelines'
# b'\n'
# b'Sign in to comment'
# b'\n'
# b'Showing '
# b'0'
# b'Sort by:'
# b'\n'
# b'Newest'
# b'\n'
# b'\n'
# b'Oldest'
# b'\n'
# b'\n'
# b'There was a problem loading comments right now. Please try again later.'
# b'5.0 out of 5 stars'
# b'love the voice control'
# b'By'
# b'David Neff'
# b'on November 20, 2017'
# b'Verified Purchase'
# b'Upgraded my Bolt to the new software, love the voice control!!!'
# b'0'
# b'Comment'
# b'|'
# b'\n      One person found this helpful.\n    '
# b'\n  Was this review helpful to you?'
# b'Yes'
# b'No'
# b'Report abuse'
# b'Comment'
# b'Insert product link'
# b"Paste the product's web address below:"
# b'Product not found. Only products offered on Amazon can be linked.'
# b'Select'
# b"What's this?"
# b'What are product links?'
# b'In the text of your review, you can link directly to any product offered on Amazon.com. To insert a product link, follow these steps:'
# b'1. Find the product you want to reference on Amazon.com'
# b'2. Copy the web address of the product'
# b'3. Click '
# b'Insert product link'
# b'4. Paste the web address in the box'
# b'5. Click '
# b'Select'
# b'6. Selecting the item displayed will insert text that looks like this: '
# b'\n        [[ASIN:014312854X'
# b'Hamlet (The Pelican Shakespeare)]]\n      '
# b'7. When your review is displayed on Amazon.com, this text will be transformed into a hyperlink, like so:'
# b'Hamlet (The Pelican Shakespeare)'
# b'You are limited to 10 product links in your review, and your link text may not be longer than 256 characters.'
# b'Talk about why you like this review, or ask a question.'
# b'Please write at least one word'
# b'You must be in good standing in the Amazon community to post.'
# b'Your message will not be posted. Please see our guidelines regarding objectionable content.'
# b'You must purchase at least one item from Amazon to post a comment'
# b'A problem occurred while submitting your comment. Please try again later.'
# b'\n        Guidelines'
# b'\n'
# b'Sign in to comment'
# b'\n'
# b'Showing '
# b'0'
# b'Sort by:'
# b'\n'
# b'Newest'
# b'\n'
# b'\n'
# b'Oldest'
# b'\n'
# b'\n'
# b'There was a problem loading comments right now. Please try again later.'
# b'1.0 out of 5 stars'
# b'One Star'
# b'By'
# b'D M.'
# b'on November 19, 2017'
# b'Verified Purchase'
# b'Major issues pairing with Tivo Mini. Issue not resolved. Returning soon if not resolved.'
# b'2'
# b'2 comments'
# b'|'
# b'Was this review helpful to you?'
# b'Yes'
# b'No'
# b'Report abuse'
# b'Comment'
# b'Insert product link'
# b"Paste the product's web address below:"
# b'Product not found. Only products offered on Amazon can be linked.'
# b'Select'
# b"What's this?"
# b'What are product links?'
# b'In the text of your review, you can link directly to any product offered on Amazon.com. To insert a product link, follow these steps:'
# b'1. Find the product you want to reference on Amazon.com'
# b'2. Copy the web address of the product'
# b'3. Click '
# b'Insert product link'
# b'4. Paste the web address in the box'
# b'5. Click '
# b'Select'
# b'6. Selecting the item displayed will insert text that looks like this: '
# b'\n        [[ASIN:014312854X'
# b'Hamlet (The Pelican Shakespeare)]]\n      '
# b'7. When your review is displayed on Amazon.com, this text will be transformed into a hyperlink, like so:'
# b'Hamlet (The Pelican Shakespeare)'
# b'You are limited to 10 product links in your review, and your link text may not be longer than 256 characters.'
# b'Talk about why you like this review, or ask a question.'
# b'Please write at least one word'
# b'You must be in good standing in the Amazon community to post.'
# b'Your message will not be posted. Please see our guidelines regarding objectionable content.'
# b'You must purchase at least one item from Amazon to post a comment'
# b'A problem occurred while submitting your comment. Please try again later.'
# b'\n        Guidelines'
# b'\n'
# b'Sign in to comment'
# b'\n'
# b'Showing '
# b'0'
# b'Sort by:'
# b'\n'
# b'Newest'
# b'\n'
# b'\n'
# b'Oldest'
# b'\n'
# b'\n'
# b'There was a problem loading comments right now. Please try again later.'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n    Questions? Get fast answers from reviewers\n  '
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n      Ask\n    '
# b'\n'
# b'Please make sure that you are posting in the form of a question.'
# b'\n'
# b'Please enter a question.'
# b'\n'
# b'\n    See all 10 answered questions\n'
# b'\n'
# b'\n'
# b'\n'
# b'Customers also viewed these items'
# b'TiVo VOX Remote to upgrade TiVo Roamio or TiVo Mini with Voice Search, Black (C00301)'
# b'by'
# b'TiVo'
# b'$44.99'
# b'3.8 out of 5 stars'
# b'5'
# b'TiVo C00221 Replacement Remote'
# b'by'
# b'TiVo'
# b'$29.99'
# b'4.6 out of 5 stars'
# b'522'
# b'TiVo Vox Remote Streaming Media Player, White - C00303'
# b'by'
# b'TiVo'
# b'$39.99'
# b'TiVo Roamio Remote (IR and RF)'
# b'by'
# b'TiVo'
# b'$39.99'
# b'4.0 out of 5 stars'
# b'102'
# b'TiVo MINI VOX Streaming Media Player, 4K UHD, With Voice Remote! (TCDA95000)'
# b'by'
# b'TiVo'
# b'$179.99'
# b'3.2 out of 5 stars'
# b'13'
# b'Need customer service? '
# b'Click here'
# b'\xe2\x80\xb9 '
# b'See all details for TiVo VOX Remote for TiVo BOLT'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Sponsored Links'
# b'\xc2\xa0 \n  '
# b'('
# b"What's this?"
# b') \n  '
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Ad feedback'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'&&&Portal&Delimiter&&&'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b"There's a problem loading this menu right now."
# b'\n'
# b'Learn more about Amazon Prime.'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n      >\n      '
# b'Get started'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Back to top'
# b'\n'
# b'Get to Know Us'
# b'Careers'
# b'About Amazon'
# b'Investor Relations'
# b'Amazon Devices'
# b'Make Money with Us'
# b'Sell on Amazon'
# b'Sell Your Services on Amazon'
# b'Sell on Amazon Business'
# b'Sell Your Apps on Amazon'
# b'Become an Affiliate'
# b'Advertise Your Products'
# b'Self-Publish with Us'
# b'Become an Amazon Vendor'
# b'\xe2\x80\xba'
# b'See all'
# b'Amazon Payment Products'
# b'Amazon Rewards Visa Signature Cards'
# b'Amazon.com Store Card'
# b'Amazon.com Corporate Credit Line'
# b'Shop with Points'
# b'Credit Card Marketplace'
# b'Reload Your Balance'
# b'Amazon Currency Converter'
# b'Let Us Help You'
# b'Your Account'
# b'Your Orders'
# b'Shipping Rates & Policies'
# b'Amazon Prime'
# b'Returns & Replacements'
# b'Manage Your Content and Devices'
# b'Amazon Assistant'
# b'Help'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'English'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'United States'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'\n'
# b'Amazon Music'
# b'Stream millions'
# b'\n'
# b'\n'
# b'Amazon Drive'
# b'Cloud storage'
# b'\n'
# b'\n'
# b'6pm'
# b'Score deals'
# b'\n'
# b'\n'
# b'AbeBooks'
# b'Books, art'
# b'\n'
# b'\n'
# b'ACX '
# b'Audiobook Publishing'
# b'\n'
# b'\n'
# b'Alexa'
# b'Actionable Analytics'
# b'\n'
# b'\n'
# b'Amazon Business'
# b'Everything For'
# b'\n'
# b'\n'
# b'\xc2\xa0'
# b'\n'
# b'\n'
# b'AmazonFresh'
# b'Groceries & More'
# b'\n'
# b'\n'
# b'AmazonGlobal'
# b'Ship Orders'
# b'\n'
# b'\n'
# b'Home Services'
# b'Handpicked Pros'
# b'\n'
# b'\n'
# b'Amazon Inspire'
# b'Digital Educational'
# b'\n'
# b'\n'
# b'Amazon Rapids'
# b'Fun stories for'
# b'\n'
# b'\n'
# b'Amazon Restaurants'
# b'Food delivery from'
# b'\n'
# b'\n'
# b'Amazon Video Direct'
# b'Video Distribution'
# b'\n'
# b'\n'
# b'\xc2\xa0'
# b'\n'
# b'\n'
# b'Amazon Web Services'
# b'Scalable Cloud'
# b'\n'
# b'\n'
# b'Audible'
# b'Download'
# b'\n'
# b'\n'
# b'AudiobookStand'
# b'Discount Audiobooks'
# b'\n'
# b'\n'
# b'Book Depository'
# b'Books With Free'
# b'\n'
# b'\n'
# b'Box Office Mojo'
# b'Find Movie'
# b'\n'
# b'\n'
# b'ComiXology'
# b'Thousands of'
# b'\n'
# b'\n'
# b'CreateSpace'
# b'Indie Print Publishing'
# b'\n'
# b'\n'
# b'\xc2\xa0'
# b'\n'
# b'\n'
# b'DPReview'
# b'Digital'
# b'\n'
# b'\n'
# b'East Dane'
# b"Designer Men's"
# b'\n'
# b'\n'
# b'Fabric'
# b'Sewing, Quilting'
# b'\n'
# b'\n'
# b'Goodreads'
# b'Book reviews'
# b'\n'
# b'\n'
# b'IMDb'
# b'Movies, TV'
# b'\n'
# b'\n'
# b'IMDbPro'
# b'Get Info Entertainment'
# b'\n'
# b'\n'
# b'Junglee.com'
# b'Shop Online'
# b'\n'
# b'\n'
# b'\xc2\xa0'
# b'\n'
# b'\n'
# b'Kindle Direct Publishing'
# b'Indie Digital Publishing'
# b'\n'
# b'\n'
# b'Prime Now'
# b'FREE 2-Hour Delivery'
# b'\n'
# b'\n'
# b'Prime Photos'
# b'Unlimited Photo Storage'
# b'\n'
# b'\n'
# b'Shopbop'
# b'Designer'
# b'\n'
# b'\n'
# b'TenMarks.com'
# b'Math Activities'
# b'\n'
# b'\n'
# b'Warehouse Deals'
# b'Open-Box'
# b'\n'
# b'\n'
# b'Whispercast'
# b'Discover & Distribute'
# b'\n'
# b'\n'
# b'\xc2\xa0'
# b'\n'
# b'\n'
# b'Whole Foods Market'
# b'America\xe2\x80\x99s Healthiest'
# b'\n'
# b'\n'
# b'Withoutabox'
# b'Submit to'
# b'\n'
# b'\n'
# b'Woot!'
# b'Deals and '
# b'\n'
# b'\n'
# b'Zappos'
# b'Shoes &'
# b'\n'
# b'\n'
# b'Souq.com'
# b'Shop Online in'
# b'\n'
# b'\n'
# b'Subscribe with Amazon'
# b'Discover & try'
# b'\n'
# b'\n'
# b'\xc2\xa0'
# b'\n'
# b'\n'
# b'\n'
# b'Conditions of Use'
# b'Privacy Notice'
# b'Interest-Based Ads'
# b'\xc2\xa9 1996-2017, Amazon.com, Inc. or its affiliates'
# b'\n'

# %%
'''
for any webpages, extract all the visible texts
'''
 
# html = urllib.request.urlopen('') # put the url here
# 
# soup = BeautifulSoup(html.read(), 'html.parser')
# texts = soup.findAll(text=True)

# def visible(element):
#     if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
#         return False
#     elif re.match('<!--.*-->', str(element)):
#         return False
#     elif re.match('[if * <![endif]', str(element)):
#         return False
#     return True
# 
# visible_texts = filter(visible, texts)
# 
# '''
# write the texts into a txt file
# '''
# with open('news.txt', 'bw') as outfile: #define the location of the output
#     for text in visible_texts:
#         try:
#             print(text.encode('utf-8'))
# 
#             outfile.write(text.encode('utf-8'))
#         except:
#             pass
            
            
'''
Extract text from fox news
'''
# html = urllib.request.urlopen('http://www.foxnews.com/politics/2017/04/04/'
#                               'susan-rice-claimed-ignorance-on-trump-team'
#                               '-surveillance-before-role-in-unmasking-revealed.html') # fill in the url
#   
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for div_article_text in soup.find_all('div',class_ = 'article-text'):
# #     print (div_article_text)
#     for p in div_article_text.find_all('p'):
#         print (p.text)
        
'''
Extract text from cnn
'''
# html = urllib.request.urlopen('http://www.cnn.com/2017/04/04/middleeast/'
#                               'idlib-syria-attack/index.html') # fill in the url
#    
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for div_body_paragraph in soup.find_all('div',class_ = 'zn-body__paragraph'):
#     print (div_body_paragraph.text)

'''
Extract text from new york time
'''
# import requests
# html = requests.get('https://www.nytimes.com/2017/04/03/us/'
#                               'justice-department-jeff-sessions-baltimore-police.html?_r=0') # fill in the url
#   
# soup = BeautifulSoup(html.content, 'html.parser')
# print (soup.title.text)
# for p_story_body_text in soup.find_all('p',class_ = 'story-body-text story-content'):
#     print (p_story_body_text.text)

'''
Extract text from huffingtonpost
'''
# html = urllib.request.urlopen('http://www.huffingtonpost.com/entry/gop-health-care-deal'
#                               '-pre-existing-conditions_us_58e39db7e4b03a26a365fdf6?') # fill in the url
#     
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for div_text in soup.find_all('div',class_ = 'content-list-component bn-content-list-text text'):
#     for p in div_text.find_all('p'):
#         print (p.text.encode('utf-8'))
'''
Extract text from yahoo
'''

# html = urllib.request.urlopen('https://www.yahoo.com/news/devin-nunes-returns-'
#                               'home-to-protests-over-his-trump-ties-155939039.html') # fill in the url
#     
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for article in soup.find_all('article'):
#     for div in article.find_all('div'):
#         for p in div.find_all('p'):
#             print (p.text)

'''
Extract text from nbcnews
'''

# html = urllib.request.urlopen('http://www.nbcnews.com/news/world/syria-chemical-attack-'
#                               'reportedly-kills-dozens-idlib-province-n742416') # fill in the url
#     
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for div in soup.find_all('div', class_ = 'article-body'):
#     for p in div.find_all('p'):
#         print (p.text)

'''
Extract text from washingtonpost
'''

# html = urllib.request.urlopen('https://www.washingtonpost.com/world/national-security/blackwater-founder-held-secret-seychelles-meeting-to-establish-trump-putin-back-channel/2017/04/03/95908a08-1648-11e7-ada0-1489b735b3a3_story.html?hpid=hp_hp-top-table-main'
#                               '_seychelles-0438pm-1%3Ahomepage%2Fstory&utm_term=.b9f05806a056') # fill in the url
#     
# soup = BeautifulSoup(html.read(), 'html.parser')
# print (soup.title.text)
# for article in soup.find_all('article', itemprop = 'articleBody'):
#     for p in article.find_all('p'):
#         print (p.text.encode('utf-8'))
