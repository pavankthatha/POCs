# %%
import tweepy
#from tweepy import Stream
#from tweepy import OAuthHandler
#from tweepy.streaming import StreamListerner
import csv

#Twitter API credentials
consumer_key = "1xnMYOD5FkrwVKakAAaAaqOyD"
consumer_secret = "hf1ADLyEPWll1rl43sGHdwl7eMWmK1LbzU6ajSxQKbwB86I15D"
access_key = "732181352326434816-XpBDVRPACxdBtChDFqxVhH2bz5nRGm0"
access_secret = "2tu6wcnVBTy6aZNtNjYrSmzzJv1pAvGI2YbTNgjXPc8rv"

NoOfTweets=1000000 # May be assuming 5 per day; would get 6 months data


def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method
    
    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []

    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=NoOfTweets)
    
    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print ("getting tweets before %s" % (oldest))
        
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=NoOfTweets,max_id=oldest)
        
        #save most recent tweets
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        
        print ("...%s tweets downloaded so far" % (len(alltweets)))

    #transform the tweepy tweets into a 2D array that will populate the csv	
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
    
    #write the csv	
    with open('%s_tweets.csv' % screen_name, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text"])
        writer.writerows(outtweets)
    
    pass
    return outtweets

if __name__ == '__main__':
    #pass in the username of the account you want to download
    #outtweets = get_all_tweets("FoxBusiness")
    #outtweets = get_all_tweets("BloombergTV")
    #outtweets = get_all_tweets("CNBC")
    #outtweets = get_all_tweets("MSNBC")
    #outtweets = get_all_tweets("CNN")
    #outtweets = get_all_tweets("thomsonreuters")
    #outtweets = get_all_tweets("Disney")
    #outtweets = get_all_tweets("generalelectric")
    #outtweets = get_all_tweets("IBM")
    
    #outtweets = get_all_tweets("MSFTnews")
    #outtweets = get_all_tweets("ProcterGamble")
    
    #outtweets = get_all_tweets("AmericanExpress")
    #outtweets = get_all_tweets("Boeing")
    
    #outtweets = get_all_tweets("DuPont_News")
    #outtweets = get_all_tweets("CocaColaCo")
    
    #outtweets = get_all_tweets("McDonaldsCorp")
    #outtweets = get_all_tweets("3M")
    #outtweets = get_all_tweets("TiVo")
    #outtweets = get_all_tweets("tivoforbusiness")
    #outtweets = get_all_tweets("TiVoSupport")
    
    
print (outtweets)
# Out:
# getting tweets before 934095549929807871
# ...40 tweets downloaded so far
# getting tweets before 930853821953269759
# ...60 tweets downloaded so far
# getting tweets before 927609904180989952
# ...80 tweets downloaded so far
# getting tweets before 926837406694641663
# ...100 tweets downloaded so far
# getting tweets before 925141748174737407
# ...120 tweets downloaded so far
# getting tweets before 919322836107448320
# ...140 tweets downloaded so far
# getting tweets before 917053757137014784
# ...160 tweets downloaded so far
# getting tweets before 915736278074822656
# ...180 tweets downloaded so far
# getting tweets before 912456959227568132
# ...200 tweets downloaded so far
# getting tweets before 908492887826079744
# ...220 tweets downloaded so far
# getting tweets before 902599051597709312
# ...240 tweets downloaded so far
# getting tweets before 860140384986570751
# ...260 tweets downloaded so far
# getting tweets before 854799383963070463
# ...280 tweets downloaded so far
# ...
